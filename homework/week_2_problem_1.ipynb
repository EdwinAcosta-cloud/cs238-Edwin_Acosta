# %% [markdown]
# I have provided a dataset with foodborne illnesses in the United states including number of cases, hospitalizations, and deaths broken down by month back to 1971 as reported by the CDC. Your task in this problem is to make a professional data visualization of this data using functions learned in class-- and ones that you find yourself-- using the matplotlib documentation. I have broken down the problem into subtasks to help you.
#
#
# Create a plot of the monthly foodborne illness cases data using a bar plot. There are some challenges you will need to figure out on your own. First, read the data in and use a set of variables that makes sense. Second, how will the x data be represented for the plot? You can't use just year or month. You can use a decimal representation e.g. January 1971 would be 1971 + 1/12 or something like that. Or you can convert the data type into a datetime object. Next, make your plot pretty by changing the following:
#
# Change both the color and edge color of the bars on the plot.
# Adjust the spacing of the tick marks to be every 5 years.
# Add labels to the x and y axes.
# 2. Find a way to clearly and elegantly summarize the cases, hospitalizations, and death data into a single plot. Avoid using a line plot, as the data has significantly different scales. Some suggestions. You could try using a grouped bar plot. You could also use a single figure with three separate panels. If you choose to use a single plot, consider using separate y axes so you can use different scales for the different datasets.
# 3. Find data online for a third variable that you hypothesize might be related to the foodborne illness outbreaks. Find a way to graphically display this data with one or more of the variables in (2). You could show them as separate panels, or together as time series on the same plot, or you might remove time as a variable altogether and make a scatter plot of cases versus second variable.
# 4. Summarize your findings for 1-3 in words.
#
#
# foodborneIllness.csv
